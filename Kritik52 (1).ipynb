# %%
import matplotlib.pyplot as plt
import random

# Initialize the vertices of the triangle and the plot
vertices = [(0, 0), (1, 0), (0.5, 0.866)]

# A function to check if a point (x, y)
# lies inside the triangle formed by
# A0, 0), (1, 0) and (0.5, 0.866)
def isInside(x1, y1, x2, y2, x3, y3, x, y):
    def area(x1, y1, x2, y2, x3, y3):
        return abs((x1 * (y2 - y3) + x2 * (y3 - y1) + x3 * (y1 - y2)) / 2.0)

    A = area(x1, y1, x2, y2, x3, y3)
    A1 = area(x, y, x2, y2, x3, y3)
    A2 = area(x1, y1, x, y, x3, y3)
    A3 = area(x1, y1, x2, y2, x, y)
    return A == A1 + A2 + A3

# Prompting the user for a seed point
while True:
    try:
        seed_x = float(input("Enter the x-coordinate of the seed point: "))
        seed_y = float(input("Enter the y-coordinate of the seed point: "))
        if isInside(0, 0, 1, 0, 0.5, 0.866, seed_x, seed_y):
            print("Valid seed point entered.")
            break
        else:
            print("The point is not inside the triangle. Please try again.")
    except ValueError:
        print("Invalid input. Please enter numerical values.")

# This is your starting point
seed = (seed_x, seed_y)

# Initialize a list where you will store your points (x_t,y_t)
# starting with the seed
points = [seed]

# Prompting the user for the number of steps
while True:
    try:
        num_steps = int(input("Enter the number of steps: "))
        if num_steps > 0:
            print(f"Number of steps set to {num_steps}.")
            break
        else:
            print("Please enter a positive integer.")
    except ValueError:
        print("Invalid input. Please enter a positive integer.")

# Perform the Chaos Game algorithm
for i in range(num_steps):
    # Choose a random vertex from the list of vertices
    next_vertex = random.choice(vertices)
    
    # Calculate the midpoint between the last point and the chosen vertex
    last_point = points[-1]
    next_point = ((last_point[0] + next_vertex[0]) / 2, (last_point[1] + next_vertex[1]) / 2)
    
    # Add the new point to the list of points
    points.append(next_point)

# Function to plot the solution set
def plot_solution(points):
    plt.scatter([p[0] for p in points], [p[1] for p in points], s=0.1)
    plt.title("Chaos Game Fractal")
    plt.show()

# plot your points
plot_solution(points)
# Out:
# Enter the x-coordinate of the seed point:  0
# Enter the y-coordinate of the seed point:  0
# Valid seed point entered.
# Enter the number of steps:  999999
# Number of steps set to 999999.

# %%
import matplotlib.pyplot as plt
import random

# Initialize the vertices of the triangle and the plot
vertices = [(0, 0), (1, 0), (0.5, 0.866)]

# A function to check if a point (x, y)
# lies inside the triangle formed by
# A0, 0), (1, 0) and (0.5, 0.866)
def isInside(x1, y1, x2, y2, x3, y3, x, y):
    def area(x1, y1, x2, y2, x3, y3):
        return abs((x1 * (y2 - y3) + x2 * (y3 - y1) + x3 * (y1 - y2)) / 2.0)

    A = area(x1, y1, x2, y2, x3, y3)
    A1 = area(x, y, x2, y2, x3, y3)
    A2 = area(x1, y1, x, y, x3, y3)
    A3 = area(x1, y1, x2, y2, x, y)
    return A == A1 + A2 + A3

# Prompting the user for a seed point
while True:
    try:
        seed_x = float(input("Enter the x-coordinate of the seed point: "))
        seed_y = float(input("Enter the y-coordinate of the seed point: "))
        if isInside(0, 0, 1, 0, 0.5, 0.866, seed_x, seed_y):
            print("Valid seed point entered.")
            break
        else:
            print("The point is not inside the triangle. Please try again.")
    except ValueError:
        print("Invalid input. Please enter numerical values.")

# This is your starting point
seed = (seed_x, seed_y)

# Initialize a list where you will store your points (x_t,y_t)
# starting with the seed
points = [seed]

# Prompting the user for the number of steps
while True:
    try:
        num_steps = int(input("Enter the number of steps: "))
        if num_steps > 0:
            print(f"Number of steps set to {num_steps}.")
            break
        else:
            print("Please enter a positive integer.")
    except ValueError:
        print("Invalid input. Please enter a positive integer.")

# Perform the Chaos Game algorithm
for i in range(num_steps):
    # Choose a random vertex from the list of vertices
    next_vertex = random.choice(vertices)
    
    # Calculate the midpoint between the last point and the chosen vertex
    last_point = points[-1]
    next_point = ((last_point[0] + next_vertex[0]) / 2, (last_point[1] + next_vertex[1]) / 2)
    
    # Add the new point to the list of points
    points.append(next_point)

# Function to plot the solution set
def plot_solution(points):
    plt.scatter([p[0] for p in points], [p[1] for p in points], s=0.1)
    plt.title("Chaos Game Fractal")
    plt.show()

# plot your points
plot_solution(points)
# Out:
# Enter the x-coordinate of the seed point:  0
# Enter the y-coordinate of the seed point:  0
# Valid seed point entered.
# Enter the number of steps:  99
# Number of steps set to 99.

# %%
"""
Chaos game explanation: The Chaos Game is a simple process that creates a fractal called the Sierpinski Triangle. 
It works by picking a random starting point inside a triangle and then repeatedly moving halfway toward one of
the triangle’s corners (chosen randomly). Over time, the points form a pattern that looks like the Sierpinski 
Triangle.


Subjective comments: It’s surprising that something so random (picking vertices) makes something so structured. 
Even though the process seems chaotic, the result is always the same fractal. 
It’s cool how simple rules create something this complicated.
"""
