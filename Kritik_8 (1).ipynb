# %%
import numpy as np

#4a
def gradient_descent(x0, y0, f, alpha, num_iterations):
    x, y = x0, y0 
    for i in range(num_iterations):
        grad_x,grad_y=grad_f_1(x, y)
        x = x-alpha*grad_x
        y = y-alpha*grad_y
    return x, y

#b

def fun_1(x, y):
    return x**2 + y**2

def grad_f_1(x, y):
    grad_x=2*x
    grad_y=2*y
    return grad_x, grad_y

# %%
# test case for a and b
gradient_descent(0.1,0.1,fun_1,0.1,10)
# Out:
# (0.010737418240000003, 0.010737418240000003)

# %%
# test case for a and b
gradient_descent(-1,1,fun_1,0.01,100)
# Out:
# (-0.13261955589475316, 0.13261955589475316)

# %%
#c
def fun_2(x, y):
  return 1-np.exp(-x**2-(y-2)**2)-2*np.exp(-x**2-(y+2)**2)

def grad_f_2(x, y):
    grad_x = 2*x*np.exp(-x**2-(y-2)**2)+4*x*np.exp(-x**2-(y+2)**2)
    grad_y = 2*(y-2)*np.exp(-x**2-(y-2)**2)+4*(y+2)*np.exp(-x**2-(y+2)**2)
    return grad_x, grad_y

# same as in a, just wanted to separate this with cells and was getting weird errors so i put it again
def gradient_descent(x0, y0, f, alpha, num_iterations):
    x, y = x0, y0 
    for i in range(num_iterations):
        grad_x, grad_y = grad_f_1(x, y)
        x = x-alpha*grad_x
        y = y-alpha*grad_y
    return x, y

# %%
# test case for c
gradient_descent(0,1,fun_2,0.01,1000)
# Out:
# (0.0, 1.6829673572159529e-09)

# %%
# test case for c
gradient_descent(0,-1,fun_2,0.01,1000)
# Out:
# (0.0, -1.6829673572159529e-09)

# %%
#plotting the function
# i don't know if it's supposed to be all together or again so i'm just gonna do it again
# hope marking is going well
# yay
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# all the stuff from a
def gradient_descent(x0, y0, f, alpha, num_iterations):
    x, y = x0, y0 
    for i in range(num_iterations):
        grad_x,grad_y=grad_f_1(x, y)
        x = x-alpha*grad_x
        y = y-alpha*grad_y
    return x, y

def fun_1(x, y):
    return x**2 + y**2

def grad_f_1(x, y):
    grad_x=2*x
    grad_y=2*y
    return grad_x, grad_y

# actually graphing
X = np.linspace(-5, 5, 100)
Y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(X, Y)
z = fun_1(x, y)  # Calculate z using the function over the grid

# Plotting
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none')
plt.show()

# %%
# ok gonna do it again for c now woohoo
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

def fun_2(x, y):
  return 1-np.exp(-x**2-(y-2)**2)-2*np.exp(-x**2-(y+2)**2)

def grad_f_2(x, y):
    grad_x = 2*x*np.exp(-x**2-(y-2)**2)+4*x*np.exp(-x**2-(y+2)**2)
    grad_y = 2*(y-2)*np.exp(-x**2-(y-2)**2)+4*(y+2)*np.exp(-x**2-(y+2)**2)
    return grad_x, grad_y

def gradient_descent(x0, y0, f, alpha, num_iterations):
    x, y = x0, y0 
    for i in range(num_iterations):
        grad_x, grad_y = grad_f_1(x, y)
        x = x-alpha*grad_x
        y = y-alpha*grad_y
    return x, y

# Create a meshgrid for the surface plot
X = np.linspace(-5, 5, 100)
Y = np.linspace(-5, 5, 100)
x, y = np.meshgrid(X, Y)
z = fun_2(x, y)  # Calculate z using the function over the grid

# Plotting
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot_surface(x, y, z, cmap='viridis', edgecolor='none')
plt.show()
